# %%
ls
# Out:
# drive/  sample_data/

# %%
cd '/content/drive/Shareddrives/CIS550/NBA stats'
# Out:
# /content/drive/Shareddrives/CIS550/NBA stats

# %%
import pandas as pd 
import numpy as np 
games= pd.read_csv('/content/drive/Shareddrives/CIS550/NBA stats/games.csv') 
games.head(5)
games = games.drop(['TEAM_ID_home', 'TEAM_ID_away'], axis =1)
games = games.dropna()
games = games.drop_duplicates(subset='GAME_ID', keep="first")

# games.loc[games['GAME_ID'] == 22000070]

games.to_csv('/content/drive/Shareddrives/CIS550/Processed data/games.csv')

# %%
games_details = pd.read_csv("/content/drive/Shareddrives/CIS550/NBA stats/games_details.csv")
games_details['START_POSITION'] = games_details['START_POSITION'].fillna('B')
games_details['COMMENT'] = games_details['COMMENT'].fillna('')
games_details['MIN'] = games_details['MIN'].fillna('')
games_details['MIN']= games_details['MIN'].astype(str)+ games_details['COMMENT'].astype(str)
games_details = games_details.drop(['TEAM_CITY', 'NICKNAME', 'COMMENT'], axis =1 )

games_details = games_details.drop_duplicates(subset=['TEAM_ID','GAME_ID', 'PLAYER_ID'], keep="first")


# games_details

games_details.to_csv('/content/drive/Shareddrives/CIS550/Processed data/games_details.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
player = pd.read_csv('/content/drive/Shareddrives/CIS550/NBA stats/players.csv')
player.head(5)

player.to_csv('/content/drive/Shareddrives/CIS550/Processed data/players.csv')

# %%
ranking =pd.read_csv("/content/drive/Shareddrives/CIS550/NBA stats/ranking.csv")
ranking.head(5)
ranking.drop(['LEAGUE_ID'], axis =1)
ranking["SEASON_ID"] = ranking["SEASON_ID"].astype(str).str.slice(1, 5)
ranking.head(5)

ranking = ranking.drop_duplicates(subset=['TEAM_ID','SEASON_ID', 'STANDINGSDATE'], keep="first")



# ranking.to_csv('/content/drive/Shareddrives/CIS550/Processed data/ranking.csv')
# Out:
# Empty DataFrame
# Columns: [TEAM_ID, LEAGUE_ID, SEASON_ID, STANDINGSDATE, CONFERENCE, TEAM, G, W, L, W_PCT, HOME_RECORD, ROAD_RECORD, RETURNTOPLAY]
# Index: []

# %%
teams = pd.read_csv("/content/drive/Shareddrives/CIS550/NBA stats/teams.csv")
teams =teams.drop(['LEAGUE_ID','MIN_YEAR','MAX_YEAR','ARENACAPACITY', 'DLEAGUEAFFILIATION'], axis= 1)
teams
# teams.to_csv('/content/drive/Shareddrives/CIS550/Processed data/teams.csv')
# Out:
#        TEAM_ID ABBREVIATION       NICKNAME  YEARFOUNDED           CITY  \
# 0   1610612737          ATL          Hawks         1949        Atlanta
# 1   1610612738          BOS        Celtics         1946         Boston
# 2   1610612740          NOP       Pelicans         2002    New Orleans
# 3   1610612741          CHI          Bulls         1966        Chicago
# 4   1610612742          DAL      Mavericks         1980         Dallas
# 5   1610612743          DEN        Nuggets         1976         Denver
# 6   1610612745          HOU        Rockets         1967        Houston
# 7   1610612746          LAC       Clippers         1970    Los Angeles
# 8   1610612747          LAL         Lakers         1948    Los Angeles
# 9   1610612748          MIA           Heat         1988          Miami
# 10  1610612749          MIL          Bucks         1968      Milwaukee
# 11  1610612750          MIN   Timberwolves         1989      Minnesota
# 12  1610612751          BKN           Nets         1976       Brooklyn
# 13  1610612752          NYK         Knicks         1946       New York
# 14  1610612753          ORL          Magic         1989        Orlando
# 15  1610612754          IND         Pacers         1976        Indiana
# 16  1610612755          PHI          76ers         1949   Philadelphia
# 17  1610612756          PHX           Suns         1968        Phoenix
# 18  1610612757          POR  Trail Blazers         1970       Portland
# 19  1610612758          SAC          Kings         1948     Sacramento
# 20  1610612759          SAS          Spurs         1976    San Antonio
# 21  1610612760          OKC        Thunder         1967  Oklahoma City
# 22  1610612761          TOR        Raptors         1995        Toronto
# 23  1610612762          UTA           Jazz         1974           Utah
# 24  1610612763          MEM      Grizzlies         1995        Memphis
# 25  1610612764          WAS        Wizards         1961     Washington
# 26  1610612765          DET        Pistons         1948        Detroit
# 27  1610612766          CHA        Hornets         1988      Charlotte
# 28  1610612739          CLE      Cavaliers         1970      Cleveland
# 29  1610612744          GSW       Warriors         1946   Golden State
#
#                          ARENA                                OWNER  \
# 0             State Farm Arena                         Tony Ressler
# 1                    TD Garden                        Wyc Grousbeck
# 2         Smoothie King Center                           Tom Benson
# 3                United Center                      Jerry Reinsdorf
# 4     American Airlines Center                           Mark Cuban
# 5                 Pepsi Center                         Stan Kroenke
# 6                Toyota Center                      Tilman Fertitta
# 7               Staples Center                        Steve Ballmer
# 8               Staples Center              Jerry Buss Family Trust
# 9       AmericanAirlines Arena                         Micky Arison
# 10                Fiserv Forum            Wesley Edens & Marc Lasry
# 11               Target Center                          Glen Taylor
# 12             Barclays Center                             Joe Tsai
# 13       Madison Square Garden            Cablevision (James Dolan)
# 14                Amway Center                           Rick DeVos
# 15     Bankers Life Fieldhouse                           Herb Simon
# 16          Wells Fargo Center                        Joshua Harris
# 17  Talking Stick Resort Arena                        Robert Sarver
# 18                 Moda Center                           Paul Allen
# 19             Golden 1 Center                       Vivek Ranadive
# 20                 AT&T Center                           Peter Holt
# 21     Chesapeake Energy Arena                         Clay Bennett
# 22            Scotiabank Arena  Maple Leaf Sports and Entertainment
# 23     Vivint Smart Home Arena                          Greg Miller
# 24                  FedExForum                          Robert Pera
# 25           Capital One Arena                          Ted Leonsis
# 26        Little Caesars Arena                            Tom Gores
# 27             Spectrum Center                       Michael Jordan
# 28         Quicken Loans Arena                          Dan Gilbert
# 29                Chase Center                            Joe Lacob
#
#      GENERALMANAGER         HEADCOACH
# 0    Travis Schlenk      Lloyd Pierce
# 1       Danny Ainge      Brad Stevens
# 2    Trajan Langdon      Alvin Gentry
# 3        Gar Forman        Jim Boylen
# 4     Donnie Nelson     Rick Carlisle
# 5      Tim Connelly    Michael Malone
# 6       Daryl Morey     Mike D'Antoni
# 7    Michael Winger        Doc Rivers
# 8       Rob Pelinka       Frank Vogel
# 9         Pat Riley    Erik Spoelstra
# 10        Jon Horst  Mike Budenholzer
# 11     Scott Layden     Ryan Saunders
# 12       Sean Marks    Kenny Atkinson
# 13      Steve Mills     David Fizdale
# 14     John Hammond    Steve Clifford
# 15  Kevin Pritchard     Nate McMillan
# 16      Elton Brand       Brett Brown
# 17      James Jones    Monty Williams
# 18      Neil Olshey      Terry Stotts
# 19      Vlade Divac       Luke Walton
# 20     Brian Wright    Gregg Popovich
# 21       Sam Presti     Billy Donovan
# 22      Masai Ujiri        Nick Nurse
# 23   Dennis Lindsey       Quin Snyder
# 24     Zach Kleiman    Taylor Jenkins
# 25   Tommy Sheppard      Scott Brooks
# 26     Ed Stefanski       Dwane Casey
# 27    Mitch Kupchak     James Borrego
# 28      Koby Altman      John Beilein
# 29        Bob Myers        Steve Kerr
